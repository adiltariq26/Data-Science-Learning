# %%
import pandas as pd

# %%
df = pd.read_csv('players_20.csv')
df.set_index('short_name',inplace =True)
df = df[['long_name','age','dob','height_cm','weight_kg','nationality','club']]
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi                 170         72   Argentina
# Cristiano Ronaldo        187         83    Portugal
# Neymar Jr                175         68      Brazil
# J. Oblak                 188         87    Slovenia
# E. Hazard                175         74     Belgium
# ...                      ...        ...         ...
# Shao Shuai               186         79    China PR
# Xiao Mingjie             177         66    China PR
# Zhang Wei                186         75    China PR
# Wang Haijian             185         74    China PR
# Pan Ximing               182         78    China PR
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# Neymar Jr                    Paris Saint-Germain
# J. Oblak                         Atlético Madrid
# E. Hazard                            Real Madrid
# ...                                          ...
# Shao Shuai                      Beijing Renhe FC
# Xiao Mingjie                    Shanghai SIPG FC
# Zhang Wei                 Hebei China Fortune FC
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [18278 rows x 7 columns]

# %% [markdown]
# # 1 Sample()

# %%
# extract 10 random elements from the "nationality" column 
df['nationality'].sample(10,random_state = 1)
# Out:
# short_name
# D. Cvetinović            Serbia
# M. Silva                Uruguay
# S. Mandash         Saudi Arabia
# I. Gruev               Bulgaria
# Kangin Lee       Korea Republic
# Marc Cardona              Spain
# R. Nteka                 France
# J. Mikel                Nigeria
# He Chao                China PR
# P. Ruffaut               France
# Name: nationality, dtype: object

# %%
df.sample(frac=0.2,random_state =1)
# Out:
#                                     long_name  age         dob  height_cm  \
# short_name
# D. Cvetinović                Dušan Cvetinović   30  1988-12-24        186
# M. Silva                        Marcelo Silva   30  1989-03-21        185
# S. Mandash               Sultan Ahmed Mandash   24  1994-10-17        167
# I. Gruev                           Ilia Gruev   19  2000-05-06        189
# Kangin Lee                     이강인 Kangin Lee   18  2001-02-19        173
# ...                                       ...  ...         ...        ...
# P. Finger                      Patrick Finger   18  2001-01-01        166
# T. Băluță                        Tudor Băluță   20  1999-03-27        191
# Adrián Maideira  Adrián Guto Maideira Almeida   35  1984-02-29        170
# Choi Chul Soon                        최철순 崔喆淳   32  1987-02-08        175
# K. Agard                         Kieran Agard   29  1989-10-10        176
#
#                  weight_kg     nationality                    club
# short_name
# D. Cvetinović           79          Serbia     Yokohama F. Marinos
# M. Silva                82         Uruguay          Real Salt Lake
# S. Mandash              63    Saudi Arabia                 Al Ahli
# I. Gruev                74        Bulgaria        SV Werder Bremen
# Kangin Lee              61  Korea Republic             Valencia CF
# ...                    ...             ...                     ...
# P. Finger               61         Germany     Eintracht Frankfurt
# T. Băluță               80         Romania  Brighton & Hove Albion
# Adrián Maideira         66          Brazil                   Goiás
# Choi Chul Soon          68  Korea Republic  Jeonbuk Hyundai Motors
# K. Agard                67         England      Milton Keynes Dons
#
# [3656 rows x 7 columns]

# %%
# upsample
df.sample(frac=2,replace = True)
# Out:
#                                     long_name  age         dob  height_cm  \
# short_name
# Oh Beom Seok                          오범석 吴范锡   34  1984-07-29        181
# E. Yao                              Eloge Yao   23  1996-01-20        182
# L. Wales                        Lachlan Wales   21  1997-10-19        180
# Oh In-Pyo                           In-Pyo Oh   22  1997-03-18        178
# D. Cuadros                      Diego Cuadros   23  1996-05-28        170
# ...                                       ...  ...         ...        ...
# G. Acampora                  Gennaro Acampora   25  1994-03-29        177
# A. Corryn                    Alexander Corryn   25  1994-01-03        177
# Venanzio Meirás  Venanzio Luis Meirás Correia   31  1988-02-29        184
# O. Shevchenko              Oleksiy Shevchenko   27  1992-02-24        188
# G. Melkadze                  Georgiy Melkadze   22  1997-04-04        182
#
#                  weight_kg     nationality               club
# short_name
# Oh Beom Seok            77  Korea Republic         Gangwon FC
# E. Yao                  76     Ivory Coast          FC Lugano
# L. Wales                74       Australia  Melbourne City FC
# Oh In-Pyo               68  Korea Republic          LASK Linz
# D. Cuadros              68        Colombia  Alianza Petrolera
# ...                    ...             ...                ...
# G. Acampora             78           Italy             Spezia
# A. Corryn               73         Belgium        KV Mechelen
# Venanzio Meirás         77          Brazil        Chapecoense
# O. Shevchenko           81         Ukraine   Shakhtar Donetsk
# G. Melkadze             84          Russia     Spartak Moscow
#
# [36556 rows x 7 columns]
